# %%
from scipy import sparse
import sys
import os
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("flickr_10k/data_10k.csv", error_bad_lines = False)
# Out:
# b'Skipping line 3: expected 3 fields, saw 5\nSkipping line 5: expected 3 fields, saw 5\nSkipping line 35: expected 3 fields, saw 5\nSkipping line 45: expected 3 fields, saw 5\nSkipping line 47: expected 3 fields, saw 4\nSkipping line 50: expected 3 fields, saw 5\nSkipping line 57: expected 3 fields, saw 4\nSkipping line 60: expected 3 fields, saw 5\nSkipping line 64: expected 3 fields, saw 6\nSkipping line 67: expected 3 fields, saw 6\nSkipping line 75: expected 3 fields, saw 4\nSkipping line 82: expected 3 fields, saw 5\nSkipping line 93: expected 3 fields, saw 5\nSkipping line 106: expected 3 fields, saw 10\nSkipping line 108: expected 3 fields, saw 5\nSkipping line 110: expected 3 fields, saw 11\nSkipping line 111: expected 3 fields, saw 5\nSkipping line 112: expected 3 fields, saw 5\nSkipping line 113: expected 3 fields, saw 4\nSkipping line 115: expected 3 fields, saw 5\nSkipping line 121: expected 3 fields, saw 6\nSkipping line 122: expected 3 fields, saw 4\nSkipping line 127: 
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
print(df.shape)
# Out:
# (11328, 1)
